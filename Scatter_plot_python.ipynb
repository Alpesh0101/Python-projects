# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df_my=pd.read_csv('data.csv', nrows=12)
df_my
# Out:
#          Date  State      Region  Confirmed  Deaths  Recovered
# 0   4/29/2020  India  Maharshtra       1939      60        252
# 1   4/29/2020  India     chennai        766    1939        455
# 2   4/29/2020  India       Delhi       3848    1939       1702
# 3   4/29/2020  India      Panvel        743      42        423
# 4   4/29/2020    NaN      Raigad         27       2          7
# 5   4/29/2020    NaN     Khargar         24       3         11
# 6   4/29/2020    NaN     Kamothe       4285     214       1192
# 7   4/29/2020    NaN       Thane       1932      30        900
# 8   4/29/2020    NaN     Austria      15402     580      12779
# 9   4/29/2020    NaN  Azerbaijan       1766      23       1267
# 10  4/29/2020    NaN     Bahamas         80      11         23
# 11  4/29/2020    NaN     Bahrain       2921       8       1455

# %%
x=df_my["Deaths"]
y=df_my["Recovered"]
plt.scatter(x,y)

# %%
plt.scatter(x,df_my['Region'], c='y', marker='^', s=200, alpha=0.5, norm=20, cmap=30, plotnonfinit=False)
plt.title("Covid 19 Record")
plt.xlabel('Death')
plt.ylabel('Recovered')
# Out:
# C:\Users\Alpesh\AppData\Local\Temp\ipykernel_13760\4000933238.py:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   plt.scatter(x,df_my['Region'], c='y', marker='^', s=200, alpha=0.5, norm=20, cmap=30, plotnonfinit=False)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 plt.scatter(x,df_my['Region'], c='y', marker='^', s=200, alpha=0.5, norm=20, cmap=30, plotnonfinit=False)
#       2 plt.title("Covid 19 Record")
#       3 plt.xlabel('Death')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2798, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2793 @_copy_docstring_and_deprecators(Axes.scatter)
#    2794 def scatter(
# ...

# %%
plt.scatter(x,df_google, c='y', s=200, alpha=0.5,marker='*', linewidths=10, edgecolors='r')
plt.title("Covid 19 Record")
plt.xlabel('Death')
plt.ylabel('Recovered')
# Out:
# Text(0, 0.5, 'Recovered')
