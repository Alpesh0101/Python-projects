# %%
# "Seaborn python tutorial.ipynb"
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# days=[1,2,3,4,5,6,7,8,9]
# temperature=[12,13,14,15,16,17,18,19]
# # create the data frame
# my_df=pd.DataFrame({'days':days, 'temperature':temperature})
# # sns.lineplot(x='days', y='temperature', data=None)
# sns.lineplot(days)
# sns.lineplot(temperature)
sns.displot([1,2,3,4,5,6,7,8,9])
sns.set(style="white")
sn=np.random.RandomState(10)
d=sn.normal(size=100)
sns.distplot(d, kde=True, color='m')
# plt.show()
# Out:
# C:\Users\Alpesh\AppData\Local\Temp\ipykernel_23344\2965606308.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d, kde=True, color='m')
# <AxesSubplot: ylabel='Count'>
